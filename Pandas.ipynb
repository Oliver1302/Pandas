# %%
## getting working directory
pwd
# Out:
# 'C:\\Users\\Jeremy Kibiru\\OneDrive\\Desktop\\cds2'

# %%
## changing working directory
cd C:\\Users\\Jeremy Kibiru\\OneDrive\\Desktop\\cds2
# Out:
# C:\Users\Jeremy Kibiru\OneDrive\Desktop\cds2

# %%
## importing pandas module
import pandas as pd

# %%
## importind DF`s into python
### when everthing is saved in one folder
Titanic = pd.read_csv("tested.csv")

# %%
### when you know where your work is saved and you dont have a common file directory
#pd.read_csv("C:/Users/Jeremy Kibiru/OneDrive/Desktop/cds2/tested.csv")

# %%
## 1st 5 obs of df customizeable (add a value in the head brackets)
Titanic.head()
Titani.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
### viewing the col names
Titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
## viewing n of rows and cols in df
Titanic.shape
# Out:
# (418, 12)

# %%
## summary stats (include all gives stats of non numeric vars)
Titanic.describe(include="all").round(2)
# Out:
#         PassengerId  Survived  Pclass              Name   Sex     Age   SibSp  \
# count        418.00    418.00  418.00               418   418  332.00  418.00
# unique          NaN       NaN     NaN               418     2     NaN     NaN
# top             NaN       NaN     NaN  Kelly, Mr. James  male     NaN     NaN
# freq            NaN       NaN     NaN                 1   266     NaN     NaN
# mean        1100.50      0.36    2.27               NaN   NaN   30.27    0.45
# std          120.81      0.48    0.84               NaN   NaN   14.18    0.90
# min          892.00      0.00    1.00               NaN   NaN    0.17    0.00
# 25%          996.25      0.00    1.00               NaN   NaN   21.00    0.00
# 50%         1100.50      0.00    3.00               NaN   NaN   27.00    0.00
# 75%         1204.75      1.00    3.00               NaN   NaN   39.00    1.00
# max         1309.00      1.00    3.00               NaN   NaN   76.00    8.00
#
# ...

# %%
## geting missing obs in the cols
Titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
## sorting DF values (sorting by age) note the use of inplace
#### ascending
Titanic.sort_values("Age",inplace=False,ascending=True)

# %%
#### descending
Titanic.sort_values("Age",inplace=True,ascending=False)

# %%
## viewing the sorted or non sorted df depending on if inplace = True/False
Titanic
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# ..           ...       ...     ...                                      ...
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
# 413         1305         0       3                       Spector, Mr. Woolf
# 416         1308         0       3                      Ware, Mr. Frederick
# 417         1309         0       3                 Peter, Master. Michael J
#
# ...

# %%
## droping duplicates in a DF
### if any are dropped the shape of the df will change (recall inplace)
Titanic.drop_duplicates(subset="PassengerId")
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# ..           ...       ...     ...                                      ...
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
# 413         1305         0       3                       Spector, Mr. Woolf
# 416         1308         0       3                      Ware, Mr. Frederick
# 417         1309         0       3                 Peter, Master. Michael J
#
# ...

# %%
### checking the shape of the dyplicate dropped df
Titanic.drop_duplicates(subset="PassengerId").shape
# Out:
# (418, 12)

# %%
### package importation
import numpy as np

# %%
### new df creation (randomized)
sales = {"Seller":[],"Profit":[],"Quantity":[]}  
for i in range(1,51):
    sales["Seller"].append("Seller"+str(np.random.randint(1,51)))
    sales["Profit"].append(np.random.randint(50,100))
    sales["Quantity"].append(np.random.randint(800,1000))

# %%
## conversion to df from dictionary
sales_df = pd.DataFrame(sales)

# %%
## duplicates dropping
sales_df.drop_duplicates("Seller",inplace=True)

# %%
## check for element length for the sales df
for i in sales_df:
    print(i, len(sales_df[i].unique()))
# Out:
# Seller 35
# Profit 28
# Quantity 33

# %%
### DF with random equal q sold and bought
sales_dict = {"seller":[],"Q_sold":[],"Q_bought":[]}
#quantity = list(np.random.randint(100,250))
for i in range(1,21):
    quantity = np.random.randint(100,250)
    sales_dict["seller"].append("Seller"+str(i))
    sales_dict["Q_sold"].append(quantity)
    sales_dict["Q_bought"].append(quantity)
# %time
# Out:
# Wall time: 0 ns

# %%
for key in sales_dict.keys():
    print(key,len(sales_dict[key]))
# Out:
# seller 20
# Q_sold 20
# Q_bought 20

# %%
sales_dict.keys()
# Out:
# dict_keys(['seller', 'Q_sold', 'Q_bought'])

# %%
np.random.randint(100,250)
# Out:
# 133

# %%
#np.arange(100,120)

# %%
#list(range(100,121))

# %%
sales_dict = {"seller":[],"Q_sold":[],"Q_bought":[]}
quantity = list(range(100,120))
for i in range(1,21):
    sales_dict["seller"].append("Seller"+str(i))
    sales_dict["Q_sold"].append(np.arange(100,120))
    sales_dict["Q_bought"].append(np.arange(100,120))

# %%
## for unique values
sales_dict = {"seller":[],"Q_sold":[],"Q_bought":[]}
quantity = list(np.arange(100,120))
for i in range(1,21):
    #quantity = np.random.randint(100,250)
    sales_dict["seller"].append("Seller"+str(i))
sales_dict["Q_sold"]=quantity
sales_dict["Q_bought"]=quantity
# %time
# Out:
# Wall time: 0 ns

# %%
sales_df2 = pd.DataFrame(sales_dict)

# %%
sales_df2["sell_p2"]= [i for i in  np.random.randint(35,40,20)]

# %%
# adding a new column (selling price)
BP = 40
SP = []
for i in range(1,21):
    SP.append(np.random.randint(35,50))
    
sales_df2["Sell_p"]= SP

# %%
sales_df2.head()
# Out:
#     seller  Q_sold  Q_bought  sell_p2  Sell_p
# 0  Seller1     100       100       39      35
# 1  Seller2     101       101       37      42
# 2  Seller3     102       102       37      42
# 3  Seller4     103       103       35      48
# 4  Seller5     104       104       37      48

# %%
#sales_df2["Sell_p"]

# %%
## doing mathematical operations on a dataframe
    
### col vs single value
sales_df2["c_o_s"]= sales_df2["Q_bought"]*BP

# %%
sales_df2.head()
# Out:
#     seller  Q_sold  Q_bought  sell_p2  Sell_p  c_o_s
# 0  Seller1     100       100       39      35   4000
# 1  Seller2     101       101       37      42   4040
# 2  Seller3     102       102       37      42   4080
# 3  Seller4     103       103       35      48   4120
# 4  Seller5     104       104       37      48   4160

# %%
## math operations (col vs col)
sales_df2["Revenue"]= sales_df2["Q_sold"]*sales_df2["Sell_p"]

# %%
sales_df2.head()
# Out:
#     seller  Q_sold  Q_bought  sell_p2  Sell_p  c_o_s  Revenue
# 0  Seller1     100       100       39      35   4000     3500
# 1  Seller2     101       101       37      42   4040     4242
# 2  Seller3     102       102       37      42   4080     4284
# 3  Seller4     103       103       35      48   4120     4944
# 4  Seller5     104       104       37      48   4160     4992

# %%
## geting profit
sales_df2["Profit"]= sales_df2["Revenue"]- sales_df2["c_o_s"]

# %%
sales_df2.head()
# Out:
#     seller  Q_sold  Q_bought  sell_p2  Sell_p  c_o_s  Revenue  Profit
# 0  Seller1     100       100       39      35   4000     3500    -500
# 1  Seller2     101       101       37      42   4040     4242     202
# 2  Seller3     102       102       37      42   4080     4284     204
# 3  Seller4     103       103       35      48   4120     4944     824
# 4  Seller5     104       104       37      48   4160     4992     832

# %%
## summary stats as a DF
xy =sales_df2.describe()[["Q_bought"]].round(2)

# %%
### row dropping indexed rows
xy.drop(["mean","count"],axis =0)
# Out:
#      Q_bought
# std      5.92
# min    100.00
# 25%    104.75
# 50%    109.50
# 75%    114.25
# max    119.00

# %%
### defining a pandas series
yy =sales_df2.describe()["Q_bought"]
type(yy)
# Out:
# pandas.core.series.Series

# %%
yy
# Out:
# count     20.00000
# mean     109.50000
# std        5.91608
# min      100.00000
# 25%      104.75000
# 50%      109.50000
# 75%      114.25000
# max      119.00000
# Name: Q_bought, dtype: float64

# %%
## drop columns
sales_df2.drop(["sell_p2","c_o_s"],axis = 1,inplace= True)

# %%
## dropping rows
sales_df2.drop(0)
# Out:
#       seller  Q_sold  Q_bought  Sell_p  Revenue  P/L
# 1    Seller2     101       101      42     4242  202
# 2    Seller3     102       102      42     4284  204
# 3    Seller4     103       103      48     4944  824
# 4    Seller5     104       104      48     4992  832
# 5    Seller6     105       105      49     5145  945
# 6    Seller7     106       106      37     3922 -318
# 7    Seller8     107       107      38     4066 -214
# 8    Seller9     108       108      36     3888 -432
# 9   Seller10     109       109      47     5123  763
# 10  Seller11     110       110      40     4400    0
# 11  Seller12     111       111      49     5439  999
# 12  Seller13     112       112      36     4032 -448
# 13  Seller14     113       113      40     4520    0
# 14  Seller15     114       114      40     4560    0
# 15  Seller16     115       115      43     4945  345
# 16  Seller17     116       116      37     4292 -348
# 17  Seller18     117       117      36     4212 -468
# ...

# %%
## renaming columns
sales_df2.columns
# Out:
# Index(['seller', 'Q_sold', 'Q_bought', 'Sell_p', 'Revenue', 'P/L'], dtype='object')

# %%
sales_df2.rename(columns={"Profit":"P/L"},inplace=True)

# %%
## categorizing using columns

# %%
category = []
for pl in sales_df2["P/L"]:
    if pl<0:
        category.append("loss")
    elif pl==0:
        category.append("recoup")
    else:
        category.append("profit")
    
#print(len(category))
sales_df2["category"]=category

# %%
## filtering data frames based on a column

# %%
filt = sales_df2["category"]=="profit"
sales_df2[filt]
# Out:
#       seller  Q_sold  Q_bought  Sell_p  Revenue  P/L category
# 1    Seller2     101       101      42     4242  202   profit
# 2    Seller3     102       102      42     4284  204   profit
# 3    Seller4     103       103      48     4944  824   profit
# 4    Seller5     104       104      48     4992  832   profit
# 5    Seller6     105       105      49     5145  945   profit
# 9   Seller10     109       109      47     5123  763   profit
# 11  Seller12     111       111      49     5439  999   profit
# 15  Seller16     115       115      43     4945  345   profit
# 18  Seller19     118       118      48     5664  944   profit
# 19  Seller20     119       119      45     5355  595   profit

# %%
sales_df2[sales_df2["category"]=="profit"]
# Out:
#       seller  Q_sold  Q_bought  Sell_p  Revenue  P/L category
# 1    Seller2     101       101      42     4242  202   profit
# 2    Seller3     102       102      42     4284  204   profit
# 3    Seller4     103       103      48     4944  824   profit
# 4    Seller5     104       104      48     4992  832   profit
# 5    Seller6     105       105      49     5145  945   profit
# 9   Seller10     109       109      47     5123  763   profit
# 11  Seller12     111       111      49     5439  999   profit
# 15  Seller16     115       115      43     4945  345   profit
# 18  Seller19     118       118      48     5664  944   profit
# 19  Seller20     119       119      45     5355  595   profit

# %%
sales_df2[sales_df2["P/L"]>0]
# Out:
#       seller  Q_sold  Q_bought  Sell_p  Revenue  P/L category
# 1    Seller2     101       101      42     4242  202   profit
# 2    Seller3     102       102      42     4284  204   profit
# 3    Seller4     103       103      48     4944  824   profit
# 4    Seller5     104       104      48     4992  832   profit
# 5    Seller6     105       105      49     5145  945   profit
# 9   Seller10     109       109      47     5123  763   profit
# 11  Seller12     111       111      49     5439  999   profit
# 15  Seller16     115       115      43     4945  345   profit
# 18  Seller19     118       118      48     5664  944   profit
# 19  Seller20     119       119      45     5355  595   profit

# %%
## filtering using multiple criteria
#### using or 
fem = Titanic[(Titanic["Age"]>=18)|(Titanic["Sex"]=="female")]

# %%
### using and
fem2 = Titanic[(Titanic["Age"]>=18)&(Titanic["Sex"]=="female")]

# %%
## indexing using loc and iloc

# %%
####iloc
##row
Titanic.iloc[0]
# Out:
# Name           Dean, Miss. Elizabeth Gladys Millvina""
# PassengerId                                       1246
# Survived                                             1
# Pclass                                               3
# Sex                                             female
# Age                                               0.17
# SibSp                                                1
# Parch                                                2
# Ticket                                       C.A. 2315
# Fare                                            20.575
# Cabin                                              NaN
# Embarked                                             S
# Name: 0, dtype: object

# %%
## iloc with columns
Titanic.iloc[:,2]
# Out:
# 354    3
# 201    3
# 281    3
# 307    3
# 250    2
#       ..
# 408    3
# 410    3
# 413    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
## rows with columns (single val)
Titanic.iloc[2,2]
# Out:
# 3

# %%
Titanic.iloc[2,:]
# Out:
# PassengerId                              1173
# Survived                                    0
# Pclass                                      3
# Name           Peacock, Master. Alfred Edward
# Sex                                      male
# Age                                      0.75
# SibSp                                       1
# Parch                                       1
# Ticket                     SOTON/O.Q. 3101315
# Fare                                   13.775
# Cabin                                     NaN
# Embarked                                    S
# Name: 281, dtype: object

# %%
## isolate all columns for specific rows (rows 2 and 3)
Titanic.iloc[[2,3,10],:]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 281         1173         0       3  Peacock, Master. Alfred Edward    male
# 307         1199         0       3       Aks, Master. Philip Frank    male
# 409         1301         1       3       Peacock, Miss. Treasteall  female
#
#       Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 281  0.75      1      1  SOTON/O.Q. 3101315  13.775   NaN        S
# 307  0.83      0      1              392091   9.350   NaN        S
# 409  3.00      1      1  SOTON/O.Q. 3101315  13.775   NaN        S

# %%
Titanic.iloc[2:10,:]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 281         1173         0       3   Peacock, Master. Alfred Edward    male
# 307         1199         0       3        Aks, Master. Philip Frank    male
# 250         1142         1       2            West, Miss. Barbara J  female
# 263         1155         1       3     Klasen, Miss. Gertrud Emilia  female
# 117         1009         1       3  Sandstrom, Miss. Beatrice Irene  female
# 296         1188         1       2            Laroche, Miss. Louise  female
# 89           981         0       2      Wells, Master. Ralph Lester    male
# 284         1176         1       3      Rosblom, Miss. Salli Helena  female
#
#       Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 281  0.75      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 307  0.83      0      1              392091   9.3500   NaN        S
# 250  0.92      1      2          C.A. 34651  27.7500   NaN        S
# ...

# %%
### using the range function
r = list(range(2,11))
Titanic.iloc[r,:]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 281         1173         0       3   Peacock, Master. Alfred Edward    male
# 307         1199         0       3        Aks, Master. Philip Frank    male
# 250         1142         1       2            West, Miss. Barbara J  female
# 263         1155         1       3     Klasen, Miss. Gertrud Emilia  female
# 117         1009         1       3  Sandstrom, Miss. Beatrice Irene  female
# 296         1188         1       2            Laroche, Miss. Louise  female
# 89           981         0       2      Wells, Master. Ralph Lester    male
# 284         1176         1       3      Rosblom, Miss. Salli Helena  female
# 409         1301         1       3        Peacock, Miss. Treasteall  female
#
#       Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 281  0.75      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 307  0.83      0      1              392091   9.3500   NaN        S
# ...

# %%
### doing for both rows and cols( note that in iloc [r,c])
Titanic.iloc[100:105,3:8]
# Out:
#                                       Name     Sex   Age  SibSp  Parch
# 246  Karnes, Mrs. J Frank (Claire Bennett)  female  22.0      0      0
# 26            Ostby, Miss. Helene Ragnhild  female  22.0      0      1
# 27                       Daher, Mr. Shedid    male  22.5      0      0
# 150  Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0      1
# 157               Lundin, Miss. Olga Elida  female  23.0      0      0

# %%
## usng loc
Titanic.loc[150:200]
# Out:
#                                                   Name  PassengerId  Survived  \
# 150                               Wright, Miss. Marion         1054         1
# 151         Kink-Heilmann, Mrs. Anton (Luise Heilmann)         1057         1
# 152                         Botsford, Mr. William Hull         1238         0
# 153             Johansson Palmquist, Mr. Oskar Leander          995         0
# 154                          Zakarian, Mr. Mapriededer         1028         0
# 155  Douglas, Mrs. Frederick Charles (Mary Helene B...         1076         1
# 156                           Clark, Mr. Walter Miller         1144         0
# 157                                 Pulbaum, Mr. Franz          943         0
# 158                                Zakarian, Mr. Ortin         1063         0
# 159                                  Strilic, Mr. Ivan         1255         0
# 160                          Jonsson, Mr. Nils Hilding         1210         0
# ...

# %%
## setting an index
Titanic.set_index("Name",inplace=True)

# %%
Titanic.loc["Danbom, Master. Gilbert Sigvard Emanuel":"Peacock, Master. Alfred Edward"]
# Out:
#                                          PassengerId  Survived  Pclass   Sex  \
# Name
# Danbom, Master. Gilbert Sigvard Emanuel         1093         0       3  male
# Peacock, Master. Alfred Edward                  1173         0       3  male
#
#                                           Age  SibSp  Parch  \
# Name
# Danbom, Master. Gilbert Sigvard Emanuel  0.33      0      2
# Peacock, Master. Alfred Edward           0.75      1      1
#
#                                                      Ticket    Fare Cabin  \
# Name
# Danbom, Master. Gilbert Sigvard Emanuel              347080  14.400   NaN
# Peacock, Master. Alfred Edward           SOTON/O.Q. 3101315  13.775   NaN
#
#                                         Embarked
# Name
# Danbom, Master. Gilbert Sigvard Emanuel        S
# Peacock, Master. Alfred Edward                 S

# %%
## dealing with missing values

# %%
Titanic.index.unique()
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
Titanic.reset_index(inplace=True)

# %%
Titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
t2 = Titanic[['Survived', 'Pclass', 'Sex', 'Age']]

# %%
t2
# Out:
#      Survived  Pclass     Sex   Age
# 0           1       3  female  0.17
# 1           0       3    male  0.33
# 2           0       3    male  0.75
# 3           0       3    male  0.83
# 4           1       2  female  0.92
# ..        ...     ...     ...   ...
# 413         1       3  female   NaN
# 414         1       3  female   NaN
# 415         0       3    male   NaN
# 416         0       3    male   NaN
# 417         0       3    male   NaN
#
# [418 rows x 4 columns]

# %%
Titanic.fillna()

# %%
## extract titles
Titles = []
for name in Titanic["Name"]:
    split_name = name.split()
    for i in split_name:
        if i[-1]==".":
            Titles.append(i)

# %%
len(Titles)
# Out:
# 418

# %%
ls3 = ["abc","dgf","ijk"]

# %%
for i in ls3:
    print(i.split())
# Out:
# ['abc']
# ['dgf']
# ['ijk']
