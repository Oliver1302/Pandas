# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
clean = pd.read_csv("cleanp2.csv")

# %%
clean
# Out:
#       Unnamed: 0  pclass  survived  \
# 0              0       1         1
# 1              1       1         1
# 2              2       1         0
# 3              3       1         0
# 4              4       1         0
# ...          ...     ...       ...
# 1304        1304       3         0
# 1305        1305       3         0
# 1306        1306       3         0
# 1307        1307       3         0
# 1308        1308       3         0
#
#                                                  name     sex   age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0    0.0
# 1                      Allison, Master. Hudson Trevor    male  92.0    1.0
# 2                        Allison, Miss. Helen Loraine  female   2.0    1.0
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0    1.0
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0    1.0
# ...                                               ...     ...   ...    ...
# ...

# %%
cols = ['pclass', 'survived', 'name', 'sex', 'age', 'sibsp',"fare",
       'parch','embarked','home.dest']

# %%
t2 =  clean[cols]

# %%
### Analyzing fare and age relationship

# %%
x = clean["fare"]

# %%
y = clean["age"]

# %%
clean.columns
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest'],
#       dtype='object')

# %%
x = clean["fare"]
y = clean["age"]
plt.figure(figsize=(7,7),dpi=100)
plt.bar(y,x )
plt.title("AGE VS FARE")
plt.show()

# %%
med = t2['fare'].median()
t2['fare'].fillna(med,inplace=True)

# %%
plt.figure(figsize=(10,10))
plt.scatter(t2["age"],t2["fare"],marker="*")

# %%
clean[clean["fare"]>1000].shape
# Out:
# (35, 15)

# %%
clean[clean["fare"]>=5123]
# Out:
#      Unnamed: 0  pclass  survived  \
# 49           49       1         1
# 50           50       1         1
# 183         183       1         1
# 302         302       1         1
#
#                                                   name     sex   age  sibsp  \
# 49                  Cardeza, Mr. Thomas Drake Martinez    male  36.0    0.0
# 50   Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0    0.0
# 183                             Lesurer, Mr. Gustave J    male  35.0    0.0
# 302                                   Ward, Miss. Anna  female  35.0    0.0
#
#      parch    ticket      fare        cabin embarked boat  body home.dest
# 49       1  PC 17755  5123.292  B51 B53 B55        C    3   NaN   AUSTRIA
# 50       1  PC 17755  5123.292  B51 B53 B55        C    3   NaN       USA
# 183      0  PC 17755  5123.292         B101        C    3   NaN       USA
# 302      0  PC 17755  5123.292          NaN        C    3   NaN       USA

# %%
t2["home.dest"].value_counts()
# Out:
# UK              329
# USA             319
# IRELAND         117
# SWEDEN          103
# FINLAND          54
# LEBANON          51
# FRANCE           36
# CANADA           35
# BULGARIA         32
# NORWAY           26
# CROATIA          22
# BELGIUM          21
# SWITZERLAND      18
# SYRIA            17
# GUERNSEY         11
# RUSSIA            9
# AUSTRIA           8
# SPAIN             8
# CHINA             8
# DENMARK           7
# INDIA             7
# WALES             7
# SCOTLAND          6
# TURKEY            6
# ARGENTINA         5
# GREECE            4
# BOSNIA            4
# SOUTH AFRICA      4
# SLOVENIA          4
# GERMANY           4
# THAILAND          3
# URUGUAY           3
# ITALY             3
# PORTUGAL          2
# Portugal          2
# AUSTRALIA         2
# Russia            1
# NETHERLANDS       1
# MYANMAR           1
# MEXICO            1
# Croatia           1
# HUNGARIA          1
# KOSOVO            1
# PERU              1
# CUBA              1
# ...

# %%
pd.DataFrame(t2["home.dest"].value_counts())
# Out:
#               home.dest
# UK                  329
# USA                 319
# IRELAND             117
# SWEDEN              103
# FINLAND              54
# LEBANON              51
# FRANCE               36
# CANADA               35
# BULGARIA             32
# NORWAY               26
# CROATIA              22
# BELGIUM              21
# SWITZERLAND          18
# SYRIA                17
# GUERNSEY             11
# RUSSIA                9
# AUSTRIA               8
# SPAIN                 8
# CHINA                 8
# DENMARK               7
# INDIA                 7
# WALES                 7
# SCOTLAND              6
# TURKEY                6
# ARGENTINA             5
# GREECE                4
# BOSNIA                4
# SOUTH AFRICA          4
# SLOVENIA              4
# GERMANY               4
# THAILAND              3
# URUGUAY               3
# ITALY                 3
# PORTUGAL              2
# Portugal              2
# AUSTRALIA             2
# Russia                1
# ...

# %%
destination = pd.DataFrame(t2["home.dest"].value_counts()).reset_index()

# %%
destination.rename(columns={"index":"d/o","home.dest":"n_p"},inplace=True)

# %%
#### Region vs Number of people

# %%
plt.figure(figsize=(7,7))
plt.bar(destination["d/o"],destination["n_p"])
plt.xticks(rotation=90)
plt.show()

# %%
destination["d/o"]=[i.lower() for i in destination["d/o"]]

# %%
destination
# Out:
#              d/o  n_p
# 0             uk  329
# 1            usa  319
# 2        ireland  117
# 3         sweden  103
# 4        finland   54
# 5        lebanon   51
# 6         france   36
# 7         canada   35
# 8       bulgaria   32
# 9         norway   26
# 10       croatia   22
# 11       belgium   21
# 12   switzerland   18
# 13         syria   17
# 14      guernsey   11
# 15        russia    9
# 16       austria    8
# 17         spain    8
# 18         china    8
# 19       denmark    7
# 20         india    7
# 21         wales    7
# 22      scotland    6
# 23        turkey    6
# 24     argentina    5
# 25        greece    4
# 26        bosnia    4
# 27  south africa    4
# 28      slovenia    4
# 29       germany    4
# 30      thailand    3
# 31       uruguay    3
# 32         italy    3
# 33      portugal    2
# 34      portugal    2
# 35     australia    2
# 36        russia    1
# 37   netherlands    1
# 38       myanmar    1
# 39        mexico    1
# ...

# %%
for name in destination["d/o"]:
    print(name.lower())
# Out:
# uk
# usa
# ireland
# sweden
# finland
# lebanon
# france
# canada
# bulgaria
# norway
# croatia
# belgium
# switzerland
# syria
# guernsey
# russia
# austria
# spain
# china
# denmark
# india
# wales
# scotland
# turkey
# argentina
# greece
# bosnia
# south africa
# slovenia
# germany
# thailand
# uruguay
# italy
# portugal
# portugal
# australia
# russia
# netherlands
# myanmar
# mexico
# croatia
# hungaria
# kosovo
# peru
# cuba
# egypt
# japan
# argentina

# %%
for i in range(1,10):
    count =+1
    print(count)
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %%
initial = 1
regr = 1
new = regr+intial
end = 10
for
